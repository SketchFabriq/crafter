# %%
import os
import gymnasium as gym
import panda_gym
from stable_baselines3 import DDPG, HerReplayBuffer, SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.noise import NormalActionNoise
import time
import numpy as np
import visioncraft
from visioncraft.baseline.callbacks import SuccessThresholdCallback, NoiseDecayCallback
from visioncraft.baseline.utils import exponential_schedule

# %%
visioncraft_root = os.path.dirname(os.path.dirname(os.path.abspath(visioncraft.__file__)))
TRAINING_DIR = os.path.join(visioncraft_root, "baseline_training")
VIDEO_DIR = os.path.join(TRAINING_DIR, "video_training")
LOG_DIR = os.path.join(TRAINING_DIR, "run_training")
MODEL_DIR = os.path.join(TRAINING_DIR, "models")


os.makedirs(LOG_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(VIDEO_DIR, exist_ok=True)

# %%
TOTAL_TIMESTEPS = [500_000, 500_000, 500_000, 500_000]
ENV_NAME = [
    "LocobotTouch-v0",
    "LocobotGrasp-v0",
    "LocobotLift-v0",
    "LocobotPickPlace-v0",
]

DDPG_PARAMS = {
    "policy": "MultiInputPolicy",
    "learning_rate": exponential_schedule(5e-5, decay_rate=0.9),
    "buffer_size": int(1e6),
    "learning_starts": 1000,
    "batch_size": 256,
    "tau": 0.005,
    "gamma": 0.99,
    "train_freq": (1, "step"),
    "gradient_steps": -1,
    "verbose": 1,
    "device": "cuda",
}

# %%
model = None
for i, (env_name, timesteps) in enumerate(zip(ENV_NAME, TOTAL_TIMESTEPS)):
    stage_name = env_name.replace("Locobot", "").replace("Env", "")
    run_id = f"stage{i+1}_{stage_name.lower()}_{int(time.time())}"
    log_path = os.path.join(LOG_DIR, run_id)
    model_path = os.path.join(MODEL_DIR, f"{run_id}.zip")
    
    print(f"--- Training Stage {i+1}: {stage_name} ---")

    # Create environment
    env = gym.make(env_name)

    env = Monitor(env, log_path)
    env = gym.wrappers.RecordVideo(
        env,
        VIDEO_DIR + f"/{run_id}",
        episode_trigger=lambda x: x % 100 == 0,  # Record less frequently if needed
        name_prefix=f"{run_id}",
    )

    # Action noise setup
    n_actions = env.action_space.shape[0]
    sigma_start, sigma_end = 0.2, 0.05
    action_noise = NormalActionNoise(mean=np.zeros(n_actions),
                                 sigma=np.full(n_actions, sigma_start))
    
    
    DDPG_PARAMS["action_noise"] = action_noise

    noise_cb = NoiseDecayCallback(n_actions, timesteps,
                              sigma_start=sigma_start,
                              sigma_end=sigma_end)


    if model is None:
        model = SAC(
            env=env,
            tensorboard_log=LOG_DIR,
            replay_buffer_class=HerReplayBuffer,
             replay_buffer_kwargs=dict(
                n_sampled_goal=4, # HER: k = 4
                goal_selection_strategy="future",
            ),
            **DDPG_PARAMS,
        )
    else:
        model.set_env(env)
        model.action_noise = (
            action_noise
        )

    callback = SuccessThresholdCallback(
        success_threshold=0.9, check_freq=1000, window_size=200, verbose=0
    )

    model.learn(
        total_timesteps=timesteps,
        log_interval=10,
        tb_log_name=run_id,
        reset_num_timesteps=(i == 0),
        callback=[callback, noise_cb],
    )
    model.save(model_path)
    print(f"Saved model to: {model_path}\n")

    env.close()

print("--- Curriculum Learning Complete ---")
# Out:
# --- Training Stage 1: Touch-v0 ---
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/base_footprintb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/bump_front_leftb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/bump_front_rightb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/bump_leftb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/bump_rightb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/button_1b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/button_2b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/button_powerb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/camera_depth_linkUsing cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to /home/vscode/ros_ws/baseline_training/run_training/stage1_touch-v0_1746014439_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 19.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 35       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 500      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 17.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 65       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 18       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 66       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1500     |
# | train/             |          |
# |    actor_loss      | -8.02    |
# |    critic_loss     | 3.37     |
# |    ent_coef        | 0.975    |
# |    ent_coef_loss   | -0.166   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 17.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 66       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -14.6    |
# |    critic_loss     | 2.12     |
# |    ent_coef        | 0.952    |
# |    ent_coef_loss   | -0.325   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 16       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 66       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | -21.3    |
# |    critic_loss     | 0.541    |
# |    ent_coef        | 0.928    |
# |    ent_coef_loss   | -0.493   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 16.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 66       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | -28.1    |
# |    critic_loss     | 0.232    |
# |    ent_coef        | 0.905    |
# |    ent_coef_loss   | -0.668   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 67       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 3500     |
# | train/             |          |
# |    actor_loss      | -34.7    |
# |    critic_loss     | 0.28     |
# |    ent_coef        | 0.883    |
# |    ent_coef_loss   | -0.837   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 67       |
# |    time_elapsed    | 59       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -41.2    |
# |    critic_loss     | 0.202    |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -1       |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 2999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 68       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 4500     |
# | train/             |          |
# |    actor_loss      | -47.5    |
# |    critic_loss     | 0.378    |
# |    ent_coef        | 0.839    |
# |    ent_coef_loss   | -1.17    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 69       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -53.6    |
# |    critic_loss     | 0.437    |
# |    ent_coef        | 0.819    |
# |    ent_coef_loss   | -1.34    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 3999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 60       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 5500     |
# | train/             |          |
# |    actor_loss      | -58.9    |
# |    critic_loss     | 0.151    |
# |    ent_coef        | 0.799    |
# |    ent_coef_loss   | -1.52    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 60       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -64.6    |
# |    critic_loss     | 0.371    |
# |    ent_coef        | 0.779    |
# |    ent_coef_loss   | -1.67    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 4999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 61       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 6500     |
# | train/             |          |
# |    actor_loss      | -69.9    |
# |    critic_loss     | 0.198    |
# |    ent_coef        | 0.76     |
# |    ent_coef_loss   | -1.84    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 62       |
# |    time_elapsed    | 111      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | -74.5    |
# |    critic_loss     | 0.16     |
# |    ent_coef        | 0.741    |
# |    ent_coef_loss   | -2.01    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 5999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 62       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 7500     |
# | train/             |          |
# |    actor_loss      | -79.7    |
# |    critic_loss     | 0.107    |
# |    ent_coef        | 0.723    |
# |    ent_coef_loss   | -2.18    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 6499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 62       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -83.7    |
# |    critic_loss     | 0.194    |
# |    ent_coef        | 0.705    |
# |    ent_coef_loss   | -2.34    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 6999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 63       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 8500     |
# | train/             |          |
# |    actor_loss      | -88.4    |
# |    critic_loss     | 0.134    |
# |    ent_coef        | 0.687    |
# |    ent_coef_loss   | -2.52    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 64       |
# |    time_elapsed    | 140      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 0.119    |
# |    ent_coef        | 0.67     |
# |    ent_coef_loss   | -2.69    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 7999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 64       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 9500     |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 0.0939   |
# |    ent_coef        | 0.654    |
# |    ent_coef_loss   | -2.85    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 8499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 64       |
# |    time_elapsed    | 155      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 0.148    |
# |    ent_coef        | 0.638    |
# |    ent_coef_loss   | -3.01    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 8999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 60       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 10500    |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 0.362    |
# |    ent_coef        | 0.622    |
# |    ent_coef_loss   | -3.19    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 60       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 0.137    |
# |    ent_coef        | 0.607    |
# |    ent_coef_loss   | -3.35    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 9999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 60       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 11500    |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 0.298    |
# |    ent_coef        | 0.592    |
# |    ent_coef_loss   | -3.53    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 10499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 13.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 61       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 1.67     |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | -3.69    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 10999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 13.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 61       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 12500    |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 3.51     |
# |    ent_coef        | 0.563    |
# |    ent_coef_loss   | -3.86    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 11499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 13.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 61       |
# |    time_elapsed    | 209      |
# |    total_timesteps | 13000    |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 0.114    |
# |    ent_coef        | 0.549    |
# |    ent_coef_loss   | -4.03    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 11999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 13.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 62       |
# |    time_elapsed    | 216      |
# |    total_timesteps | 13500    |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 0.0764   |
# |    ent_coef        | 0.536    |
# |    ent_coef_loss   | -4.18    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 12499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 13.1     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 62       |
# |    time_elapsed    | 222      |
# |    total_timesteps | 13988    |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 0.0966   |
# |    ent_coef        | 0.523    |
# |    ent_coef_loss   | -4.36    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 12987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 13.1     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 62       |
# |    time_elapsed    | 230      |
# |    total_timesteps | 14488    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 0.164    |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | -4.53    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 13487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 13.3     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 63       |
# |    time_elapsed    | 237      |
# |    total_timesteps | 14988    |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 0.208    |
# |    ent_coef        | 0.497    |
# |    ent_coef_loss   | -4.7     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 13987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 13.3     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 60       |
# |    time_elapsed    | 256      |
# |    total_timesteps | 15488    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 0.0997   |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -4.86    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 14487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 12.2     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 60       |
# |    time_elapsed    | 263      |
# |    total_timesteps | 15988    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 0.246    |
# |    ent_coef        | 0.473    |
# |    ent_coef_loss   | -5.03    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 14987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 12.5     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 60       |
# |    time_elapsed    | 271      |
# |    total_timesteps | 16488    |
# | train/             |          |
# |    actor_loss      | -132     |
# |    critic_loss     | 0.225    |
# |    ent_coef        | 0.462    |
# |    ent_coef_loss   | -5.19    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 15487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 12.3     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 60       |
# |    time_elapsed    | 279      |
# |    total_timesteps | 16988    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 0.278    |
# |    ent_coef        | 0.45     |
# |    ent_coef_loss   | -5.37    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 15987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 12.1     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 61       |
# |    time_elapsed    | 286      |
# |    total_timesteps | 17488    |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 0.0897   |
# |    ent_coef        | 0.439    |
# |    ent_coef_loss   | -5.51    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 16487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 12.9     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 61       |
# |    time_elapsed    | 293      |
# |    total_timesteps | 17988    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 0.288    |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | -5.65    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 16987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 12.8     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 61       |
# |    time_elapsed    | 299      |
# |    total_timesteps | 18488    |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 0.277    |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | -5.82    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 17487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 13.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 61       |
# |    time_elapsed    | 308      |
# |    total_timesteps | 18988    |
# | train/             |          |
# |    actor_loss      | -139     |
# |    critic_loss     | 0.16     |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -5.98    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 17987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 62       |
# |    time_elapsed    | 314      |
# |    total_timesteps | 19488    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 1.42     |
# |    ent_coef        | 0.398    |
# |    ent_coef_loss   | -6.12    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 18487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 62       |
# |    time_elapsed    | 321      |
# |    total_timesteps | 19988    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 0.0769   |
# |    ent_coef        | 0.388    |
# |    ent_coef_loss   | -6.3     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 18987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 60       |
# |    time_elapsed    | 341      |
# |    total_timesteps | 20488    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 0.146    |
# |    ent_coef        | 0.378    |
# |    ent_coef_loss   | -6.51    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 19487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 60       |
# |    time_elapsed    | 348      |
# |    total_timesteps | 20988    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 0.179    |
# |    ent_coef        | 0.369    |
# |    ent_coef_loss   | -6.65    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 19987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 60       |
# |    time_elapsed    | 355      |
# |    total_timesteps | 21488    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 0.28     |
# |    ent_coef        | 0.36     |
# |    ent_coef_loss   | -6.76    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 20487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 60       |
# |    time_elapsed    | 362      |
# |    total_timesteps | 21988    |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 0.1      |
# |    ent_coef        | 0.351    |
# |    ent_coef_loss   | -7       |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 20987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 60       |
# |    time_elapsed    | 369      |
# |    total_timesteps | 22488    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.503    |
# |    ent_coef        | 0.342    |
# |    ent_coef_loss   | -7.12    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 21487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 61       |
# |    time_elapsed    | 376      |
# |    total_timesteps | 22988    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.118    |
# |    ent_coef        | 0.334    |
# |    ent_coef_loss   | -7.29    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 21987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 61       |
# |    time_elapsed    | 383      |
# |    total_timesteps | 23488    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.269    |
# |    ent_coef        | 0.326    |
# |    ent_coef_loss   | -7.47    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 22487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 61       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 23988    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 0.215    |
# |    ent_coef        | 0.318    |
# |    ent_coef_loss   | -7.6     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 22987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 61       |
# |    time_elapsed    | 399      |
# |    total_timesteps | 24488    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.121    |
# |    ent_coef        | 0.31     |
# |    ent_coef_loss   | -7.77    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 23487    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 13.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 61       |
# |    time_elapsed    | 406      |
# |    total_timesteps | 24988    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 0.21     |
# |    ent_coef        | 0.302    |
# |    ent_coef_loss   | -8.03    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 23987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 13.9     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 59       |
# |    time_elapsed    | 425      |
# |    total_timesteps | 25484    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.207    |
# |    ent_coef        | 0.295    |
# |    ent_coef_loss   | -8.13    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 24483    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 14.3     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 60       |
# |    time_elapsed    | 432      |
# |    total_timesteps | 25976    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 0.322    |
# |    ent_coef        | 0.288    |
# |    ent_coef_loss   | -8.35    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 24975    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 14       |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 60       |
# |    time_elapsed    | 439      |
# |    total_timesteps | 26470    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 0.176    |
# |    ent_coef        | 0.281    |
# |    ent_coef_loss   | -8.43    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 25469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 14.4     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 60       |
# |    time_elapsed    | 446      |
# |    total_timesteps | 26970    |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 0.0672   |
# |    ent_coef        | 0.274    |
# |    ent_coef_loss   | -8.68    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 25969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 14.5     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 60       |
# |    time_elapsed    | 454      |
# |    total_timesteps | 27470    |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 0.142    |
# |    ent_coef        | 0.267    |
# |    ent_coef_loss   | -8.85    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 26469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 14.6     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 60       |
# |    time_elapsed    | 461      |
# |    total_timesteps | 27970    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 0.307    |
# |    ent_coef        | 0.261    |
# |    ent_coef_loss   | -9.01    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 26969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 14.1     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 60       |
# |    time_elapsed    | 468      |
# |    total_timesteps | 28470    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 0.109    |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | -9.11    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 27469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 14.3     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 60       |
# |    time_elapsed    | 475      |
# |    total_timesteps | 28970    |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 0.14     |
# |    ent_coef        | 0.248    |
# |    ent_coef_loss   | -9.26    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 27969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 14.8     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 61       |
# |    time_elapsed    | 482      |
# |    total_timesteps | 29470    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 0.131    |
# |    ent_coef        | 0.242    |
# |    ent_coef_loss   | -9.42    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 28469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 14.9     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 61       |
# |    time_elapsed    | 489      |
# |    total_timesteps | 29970    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 82.1     |
# |    ent_coef        | 0.236    |
# |    ent_coef_loss   | -9.54    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 28969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 14.9     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 59       |
# |    time_elapsed    | 509      |
# |    total_timesteps | 30470    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.23     |
# |    ent_coef_loss   | -9.72    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 29469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 14.9     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 59       |
# |    time_elapsed    | 517      |
# |    total_timesteps | 30970    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.111    |
# |    ent_coef        | 0.225    |
# |    ent_coef_loss   | -9.97    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 29969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 630      |
# |    fps             | 60       |
# |    time_elapsed    | 524      |
# |    total_timesteps | 31470    |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 0.121    |
# |    ent_coef        | 0.219    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 30469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 60       |
# |    time_elapsed    | 531      |
# |    total_timesteps | 31970    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 0.0883   |
# |    ent_coef        | 0.214    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 30969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 60       |
# |    time_elapsed    | 538      |
# |    total_timesteps | 32470    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.184    |
# |    ent_coef        | 0.209    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 31469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 60       |
# |    time_elapsed    | 546      |
# |    total_timesteps | 32970    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.227    |
# |    ent_coef        | 0.203    |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 31969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 670      |
# |    fps             | 60       |
# |    time_elapsed    | 553      |
# |    total_timesteps | 33470    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 0.109    |
# |    ent_coef        | 0.198    |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 32469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 60       |
# |    time_elapsed    | 559      |
# |    total_timesteps | 33970    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 0.117    |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 32969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.5     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 690      |
# |    fps             | 60       |
# |    time_elapsed    | 567      |
# |    total_timesteps | 34470    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 0.141    |
# |    ent_coef        | 0.189    |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 33469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 60       |
# |    time_elapsed    | 574      |
# |    total_timesteps | 34970    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 0.0922   |
# |    ent_coef        | 0.184    |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 33969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 710      |
# |    fps             | 59       |
# |    time_elapsed    | 594      |
# |    total_timesteps | 35470    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 0.127    |
# |    ent_coef        | 0.18     |
# |    ent_coef_loss   | -11.2    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 34469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 59       |
# |    time_elapsed    | 602      |
# |    total_timesteps | 35970    |
# | train/             |          |
# |    actor_loss      | -141     |
# |    critic_loss     | 0.0923   |
# |    ent_coef        | 0.175    |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 34969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 730      |
# |    fps             | 59       |
# |    time_elapsed    | 609      |
# |    total_timesteps | 36470    |
# | train/             |          |
# |    actor_loss      | -141     |
# |    critic_loss     | 0.0599   |
# |    ent_coef        | 0.171    |
# |    ent_coef_loss   | -11.5    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 35469    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 59       |
# |    time_elapsed    | 616      |
# |    total_timesteps | 36970    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 0.0765   |
# |    ent_coef        | 0.167    |
# |    ent_coef_loss   | -11.6    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 35969    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 14.3     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 60       |
# |    time_elapsed    | 623      |
# |    total_timesteps | 37470    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 80.1     |
# ...
# |    n_updates       | 386954   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | 24.4     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 7820     |
# |    fps             | 58       |
# |    time_elapsed    | 6663     |
# |    total_timesteps | 388421   |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 1.53     |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | 1.11     |
# |    learning_rate   | 4.61e-05 |
# |    n_updates       | 387420   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | 24.2     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 7830     |
# |    fps             | 58       |
# |    time_elapsed    | 6670     |
# |    total_timesteps | 388921   |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 2.19     |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 4.61e-05 |
# |    n_updates       | 387920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | 24.2     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 7840     |
# |    fps             | 58       |
# |    time_elapsed    | 6677     |
# |    total_timesteps | 389413   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | 0.0999   |
# |    learning_rate   | 4.61e-05 |
# |    n_updates       | 388412   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | 24.3     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 7850     |
# |    fps             | 58       |
# |    time_elapsed    | 6685     |
# |    total_timesteps | 389913   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.551    |
# |    ent_coef        | 0.0423   |
# |    ent_coef_loss   | -0.35    |
# |    learning_rate   | 4.61e-05 |
# |    n_updates       | 388912   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.4     |
# |    ep_rew_mean     | 23.9     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 7860     |
# |    fps             | 58       |
# |    time_elapsed    | 6692     |
# |    total_timesteps | 390408   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.522    |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | 0.472    |
# |    learning_rate   | 4.61e-05 |
# |    n_updates       | 389407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.4     |
# |    ep_rew_mean     | 24.3     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 7870     |
# |    fps             | 58       |
# |    time_elapsed    | 6699     |
# |    total_timesteps | 390908   |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 2.2      |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | 0.278    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 389907   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.3     |
# |    ep_rew_mean     | 23.7     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 7880     |
# |    fps             | 58       |
# |    time_elapsed    | 6706     |
# |    total_timesteps | 391394   |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 0.822    |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | 0.71     |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 390393   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.3     |
# |    ep_rew_mean     | 23.9     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 7890     |
# |    fps             | 58       |
# |    time_elapsed    | 6713     |
# |    total_timesteps | 391894   |
# | train/             |          |
# |    actor_loss      | -191     |
# |    critic_loss     | 0.41     |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | 0.708    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 390893   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.3     |
# |    ep_rew_mean     | 24.1     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 7900     |
# |    fps             | 58       |
# |    time_elapsed    | 6721     |
# |    total_timesteps | 392394   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.8      |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | 0.844    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 391393   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | 23.8     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 7910     |
# |    fps             | 58       |
# |    time_elapsed    | 6741     |
# |    total_timesteps | 392866   |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 0.916    |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | -0.243   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 391865   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 23.8     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 7920     |
# |    fps             | 58       |
# |    time_elapsed    | 6748     |
# |    total_timesteps | 393366   |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 93.3     |
# |    ent_coef        | 0.0425   |
# |    ent_coef_loss   | 0.354    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 392365   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | 24.2     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 7930     |
# |    fps             | 58       |
# |    time_elapsed    | 6755     |
# |    total_timesteps | 393834   |
# | train/             |          |
# |    actor_loss      | -191     |
# |    critic_loss     | 0.767    |
# |    ent_coef        | 0.0423   |
# |    ent_coef_loss   | -0.883   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 392833   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.8     |
# |    ep_rew_mean     | 23.6     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 7940     |
# |    fps             | 58       |
# |    time_elapsed    | 6761     |
# |    total_timesteps | 394291   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.422    |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | -0.857   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 393290   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | 23.5     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 7950     |
# |    fps             | 58       |
# |    time_elapsed    | 6768     |
# |    total_timesteps | 394775   |
# | train/             |          |
# |    actor_loss      | -190     |
# |    critic_loss     | 0.444    |
# |    ent_coef        | 0.042    |
# |    ent_coef_loss   | -0.478   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 393774   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | 23.9     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 7960     |
# |    fps             | 58       |
# |    time_elapsed    | 6774     |
# |    total_timesteps | 395270   |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 0.58     |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | 0.302    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 394269   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.6     |
# |    ep_rew_mean     | 23.8     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 7970     |
# |    fps             | 58       |
# |    time_elapsed    | 6782     |
# |    total_timesteps | 395770   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.441    |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | -0.421   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 394769   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | 24.2     |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 7980     |
# |    fps             | 58       |
# |    time_elapsed    | 6789     |
# |    total_timesteps | 396260   |
# | train/             |          |
# |    actor_loss      | -190     |
# |    critic_loss     | 0.612    |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | -0.939   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 395259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | 24.5     |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 7990     |
# |    fps             | 58       |
# |    time_elapsed    | 6797     |
# |    total_timesteps | 396749   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.378    |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | 0.568    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 395748   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | 24.8     |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 8000     |
# |    fps             | 58       |
# |    time_elapsed    | 6805     |
# |    total_timesteps | 397249   |
# | train/             |          |
# |    actor_loss      | -189     |
# |    critic_loss     | 0.845    |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | -0.22    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 396248   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.8     |
# |    ep_rew_mean     | 24.8     |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 8010     |
# |    fps             | 58       |
# |    time_elapsed    | 6825     |
# |    total_timesteps | 397742   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.374    |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | -0.655   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 396741   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.8     |
# |    ep_rew_mean     | 24.9     |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 8020     |
# |    fps             | 58       |
# |    time_elapsed    | 6833     |
# |    total_timesteps | 398242   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.557    |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | 0.645    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 397241   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | 24.7     |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 8030     |
# |    fps             | 58       |
# |    time_elapsed    | 6840     |
# |    total_timesteps | 398740   |
# | train/             |          |
# |    actor_loss      | -186     |
# |    critic_loss     | 0.54     |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | -0.177   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 397739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 25.1     |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 8040     |
# |    fps             | 58       |
# |    time_elapsed    | 6847     |
# |    total_timesteps | 399240   |
# | train/             |          |
# |    actor_loss      | -190     |
# |    critic_loss     | 0.757    |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.259    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 398239   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | 25       |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 8050     |
# |    fps             | 58       |
# |    time_elapsed    | 6855     |
# |    total_timesteps | 399740   |
# | train/             |          |
# |    actor_loss      | -189     |
# |    critic_loss     | 0.803    |
# |    ent_coef        | 0.0398   |
# |    ent_coef_loss   | 0.504    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 398739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.7     |
# |    ep_rew_mean     | 25.2     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 8060     |
# |    fps             | 58       |
# |    time_elapsed    | 6861     |
# |    total_timesteps | 400240   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 1.12     |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | 0.748    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 399239   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.7     |
# |    ep_rew_mean     | 24.7     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 8070     |
# |    fps             | 58       |
# |    time_elapsed    | 6869     |
# |    total_timesteps | 400740   |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 0.785    |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | 0.467    |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 399739   |
# ---------------------------------
