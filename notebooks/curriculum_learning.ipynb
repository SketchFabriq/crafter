# %%
import os
import gymnasium as gym
import panda_gym
from stable_baselines3 import DDPG, HerReplayBuffer
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.noise import NormalActionNoise
import time
import numpy as np
import visioncraft
from visioncraft.baseline.callbacks import SuccessThresholdCallback, NoiseDecayCallback
from visioncraft.baseline.utils import exponential_schedule
# Out:
# pybullet build time: Jan 29 2025 23:19:57

# %%
visioncraft_root = os.path.dirname(os.path.dirname(os.path.abspath(visioncraft.__file__)))
TRAINING_DIR = os.path.join(visioncraft_root, "baseline_training")
VIDEO_DIR = os.path.join(TRAINING_DIR, "video_training")
LOG_DIR = os.path.join(TRAINING_DIR, "run_training")
MODEL_DIR = os.path.join(TRAINING_DIR, "models")


os.makedirs(LOG_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(VIDEO_DIR, exist_ok=True)

# %%
TOTAL_TIMESTEPS = [600_000, 600_000, 600_000, 600_000]
ENV_NAME = [
    "LocobotTouch-v0",
    "LocobotGrasp-v0",
    "LocobotLift-v0",
    "LocobotPickPlace-v0",
]

DDPG_PARAMS = {
    "policy": "MultiInputPolicy",
    "learning_rate": exponential_schedule(5e-5, decay_rate=0.9),
    "buffer_size": int(1e6),
    "learning_starts": 1000,
    "batch_size": 256,
    "tau": 0.005,
    "gamma": 0.99,
    "train_freq": (1, "step"),
    "gradient_steps": -1,
    "verbose": 1,
    "device": "cuda",
}

# %%
model = None
for i, (env_name, timesteps) in enumerate(zip(ENV_NAME, TOTAL_TIMESTEPS)):
    stage_name = env_name.replace("Locobot", "").replace("Env", "")
    run_id = f"stage{i+1}_{stage_name.lower()}_{int(time.time())}"
    log_path = os.path.join(LOG_DIR, run_id)
    model_path = os.path.join(MODEL_DIR, f"{run_id}.zip")
    
    print(f"--- Training Stage {i+1}: {stage_name} ---")

    # Create environment
    env = gym.make(env_name)

    env = Monitor(env, log_path)
    env = gym.wrappers.RecordVideo(
        env,
        VIDEO_DIR + f"/{run_id}",
        episode_trigger=lambda x: x % 100 == 0,  # Record less frequently if needed
        name_prefix=f"{run_id}",
    )

    # Action noise setup
    n_actions = env.action_space.shape[0]
    sigma_start, sigma_end = 0.2, 0.05
    action_noise = NormalActionNoise(mean=np.zeros(n_actions),
                                 sigma=np.full(n_actions, sigma_start))
    
    
    DDPG_PARAMS["action_noise"] = action_noise

    noise_cb = NoiseDecayCallback(n_actions, timesteps,
                              sigma_start=sigma_start,
                              sigma_end=sigma_end)


    if model is None:
        model = DDPG(
            env=env,
            tensorboard_log=LOG_DIR,
            replay_buffer_class=HerReplayBuffer,
             replay_buffer_kwargs=dict(
                n_sampled_goal=4, # HER: k = 4
                goal_selection_strategy="future",
            ),
            **DDPG_PARAMS,
        )
    else:
        model.set_env(env)
        model.action_noise = (
            action_noise
        )

    callback = SuccessThresholdCallback(
        success_threshold=0.9, check_freq=1000, window_size=200, verbose=0
    )

    model.learn(
        total_timesteps=timesteps,
        log_interval=10,
        tb_log_name=run_id,
        reset_num_timesteps=(i == 0),
        callback=[callback, noise_cb],
    )
    model.save(model_path)
    print(f"Saved model to: {model_path}\n")

    env.close()

print("--- Curriculum Learning Complete ---")
# Out:
# --- Training Stage 1: Touch-v0 ---
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/base_footprintb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/bump_front_leftb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/bump_front_rightb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/bump_leftb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/bump_rightb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/button_1b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/button_2b3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/button_powerb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# No inertial data for link, using mass=1, localinertiadiagonal = 1,1,1, identity local inertial frameb3Warning[examples/Importers/ImportURDFDemo/BulletUrdfImporter.cpp,126]:
# locobot/camera_depth_linkUsing cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to /home/vscode/ros_ws/baseline_training/run_training/stage1_touch-v0_1745988258_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.52     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 34       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 500      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 11.9     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 64       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 10       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 64       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1500     |
# | train/             |          |
# |    actor_loss      | -2.03    |
# |    critic_loss     | 0.0697   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.52     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 62       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -3.41    |
# |    critic_loss     | 0.0292   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.76     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 59       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | -5.32    |
# |    critic_loss     | 0.027    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 8.88     |
# |    success_rate    | 0.0167   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 54       |
# |    time_elapsed    | 54       |
# |    total_timesteps | 2967     |
# | train/             |          |
# |    actor_loss      | -6.52    |
# |    critic_loss     | 0.0201   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1966     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | 9.45     |
# |    success_rate    | 0.0429   |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 52       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 3398     |
# | train/             |          |
# |    actor_loss      | -7.71    |
# |    critic_loss     | 0.024    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 2397     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | 9.77     |
# |    success_rate    | 0.0375   |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 49       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 3898     |
# | train/             |          |
# |    actor_loss      | -9.64    |
# |    critic_loss     | 0.0289   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 2897     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | 10.3     |
# |    success_rate    | 0.0333   |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 45       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 4398     |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 0.0494   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 3397     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | 11.5     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 44       |
# |    time_elapsed    | 109      |
# |    total_timesteps | 4896     |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.0829   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 3895     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.4     |
# |    ep_rew_mean     | 12.6     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 39       |
# |    time_elapsed    | 134      |
# |    total_timesteps | 5338     |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.836    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 4337     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.4     |
# |    ep_rew_mean     | 13.1     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 40       |
# |    time_elapsed    | 145      |
# |    total_timesteps | 5838     |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 0.0554   |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 4837     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.9     |
# |    ep_rew_mean     | 14.4     |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 40       |
# |    time_elapsed    | 154      |
# |    total_timesteps | 6287     |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 2.53     |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 5286     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.4     |
# |    ep_rew_mean     | 15.3     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 40       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 6742     |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 0.0747   |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 5741     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47       |
# |    ep_rew_mean     | 16.1     |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 40       |
# |    time_elapsed    | 177      |
# |    total_timesteps | 7198     |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 0.142    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 6197     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.2     |
# |    ep_rew_mean     | 17.5     |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 40       |
# |    time_elapsed    | 190      |
# |    total_timesteps | 7691     |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 1.75     |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 6690     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.9     |
# |    ep_rew_mean     | 17.7     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 41       |
# |    time_elapsed    | 199      |
# |    total_timesteps | 8191     |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 0.228    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 7190     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.9     |
# |    ep_rew_mean     | 18.9     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 41       |
# |    time_elapsed    | 208      |
# |    total_timesteps | 8691     |
# | train/             |          |
# |    actor_loss      | -26.9    |
# |    critic_loss     | 0.0993   |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 7690     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.9     |
# |    ep_rew_mean     | 19.7     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 41       |
# |    time_elapsed    | 219      |
# |    total_timesteps | 9191     |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 0.0666   |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 8190     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | 19.5     |
# |    success_rate    | 0.08     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 41       |
# |    time_elapsed    | 232      |
# |    total_timesteps | 9691     |
# | train/             |          |
# |    actor_loss      | -30.6    |
# |    critic_loss     | 3.83     |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 8690     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | 19.9     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 40       |
# |    time_elapsed    | 254      |
# |    total_timesteps | 10191    |
# | train/             |          |
# |    actor_loss      | -32.7    |
# |    critic_loss     | 4.16     |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 9190     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.5     |
# |    ep_rew_mean     | 19.1     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 40       |
# |    time_elapsed    | 266      |
# |    total_timesteps | 10691    |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 0.166    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 9690     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | 17.9     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 40       |
# |    time_elapsed    | 276      |
# |    total_timesteps | 11191    |
# | train/             |          |
# |    actor_loss      | -37.2    |
# |    critic_loss     | 0.155    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 10190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 17.4     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 41       |
# |    time_elapsed    | 283      |
# |    total_timesteps | 11691    |
# | train/             |          |
# |    actor_loss      | -38.5    |
# |    critic_loss     | 0.155    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 10690    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.9     |
# |    ep_rew_mean     | 16.8     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 41       |
# |    time_elapsed    | 291      |
# |    total_timesteps | 12191    |
# | train/             |          |
# |    actor_loss      | -40.9    |
# |    critic_loss     | 0.153    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 11190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 15.6     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 42       |
# |    time_elapsed    | 299      |
# |    total_timesteps | 12691    |
# | train/             |          |
# |    actor_loss      | -42.6    |
# |    critic_loss     | 0.141    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 11690    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 15.4     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 41       |
# |    time_elapsed    | 313      |
# |    total_timesteps | 13146    |
# | train/             |          |
# |    actor_loss      | -44.6    |
# |    critic_loss     | 0.998    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 12145    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 14.8     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 42       |
# |    time_elapsed    | 324      |
# |    total_timesteps | 13646    |
# | train/             |          |
# |    actor_loss      | -44.8    |
# |    critic_loss     | 4.6      |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 12645    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 14       |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 42       |
# |    time_elapsed    | 331      |
# |    total_timesteps | 14146    |
# | train/             |          |
# |    actor_loss      | -47.2    |
# |    critic_loss     | 0.692    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 13145    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 13.2     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 42       |
# |    time_elapsed    | 344      |
# |    total_timesteps | 14646    |
# | train/             |          |
# |    actor_loss      | -48.7    |
# |    critic_loss     | 0.172    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 13645    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 12.3     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 40       |
# |    time_elapsed    | 371      |
# |    total_timesteps | 15146    |
# | train/             |          |
# |    actor_loss      | -50.7    |
# |    critic_loss     | 0.194    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 14145    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 12.3     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 41       |
# |    time_elapsed    | 381      |
# |    total_timesteps | 15646    |
# | train/             |          |
# |    actor_loss      | -53.2    |
# |    critic_loss     | 0.242    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 14645    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 12.3     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 41       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 16146    |
# | train/             |          |
# |    actor_loss      | -56.3    |
# |    critic_loss     | 0.229    |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 15145    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 12.4     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 41       |
# |    time_elapsed    | 402      |
# |    total_timesteps | 16646    |
# | train/             |          |
# |    actor_loss      | -55.5    |
# |    critic_loss     | 11.7     |
# |    learning_rate   | 4.99e-05 |
# |    n_updates       | 15645    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 12.6     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 41       |
# |    time_elapsed    | 413      |
# |    total_timesteps | 17146    |
# | train/             |          |
# |    actor_loss      | -58.4    |
# |    critic_loss     | 0.225    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 16145    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.2     |
# |    ep_rew_mean     | 12       |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 41       |
# |    time_elapsed    | 428      |
# |    total_timesteps | 17610    |
# | train/             |          |
# |    actor_loss      | -60.9    |
# |    critic_loss     | 10.3     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 16609    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.1     |
# |    ep_rew_mean     | 12.2     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 40       |
# |    time_elapsed    | 442      |
# |    total_timesteps | 18057    |
# | train/             |          |
# |    actor_loss      | -60.8    |
# |    critic_loss     | 0.319    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 17056    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.7     |
# |    ep_rew_mean     | 12       |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 40       |
# |    time_elapsed    | 453      |
# |    total_timesteps | 18517    |
# | train/             |          |
# |    actor_loss      | -62.1    |
# |    critic_loss     | 12.4     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 17516    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48       |
# |    ep_rew_mean     | 12.8     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 41       |
# |    time_elapsed    | 461      |
# |    total_timesteps | 18946    |
# | train/             |          |
# |    actor_loss      | -63.4    |
# |    critic_loss     | 0.556    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 17945    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.5     |
# |    ep_rew_mean     | 13.3     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 41       |
# |    time_elapsed    | 469      |
# |    total_timesteps | 19392    |
# | train/             |          |
# |    actor_loss      | -66.7    |
# |    critic_loss     | 13       |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 18391    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.8     |
# |    ep_rew_mean     | 13.8     |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 40       |
# |    time_elapsed    | 494      |
# |    total_timesteps | 19825    |
# | train/             |          |
# |    actor_loss      | -66.2    |
# |    critic_loss     | 15.6     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 18824    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.7     |
# |    ep_rew_mean     | 14.1     |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 40       |
# |    time_elapsed    | 505      |
# |    total_timesteps | 20314    |
# | train/             |          |
# |    actor_loss      | -69      |
# |    critic_loss     | 0.347    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 19313    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46       |
# |    ep_rew_mean     | 15.6     |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 40       |
# |    time_elapsed    | 514      |
# |    total_timesteps | 20746    |
# | train/             |          |
# |    actor_loss      | -69      |
# |    critic_loss     | 15.7     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 19745    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | 15.8     |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 40       |
# |    time_elapsed    | 523      |
# |    total_timesteps | 21204    |
# | train/             |          |
# |    actor_loss      | -70      |
# |    critic_loss     | 14.9     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 20203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | 16.1     |
# |    success_rate    | 0.15     |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 40       |
# |    time_elapsed    | 531      |
# |    total_timesteps | 21704    |
# | train/             |          |
# |    actor_loss      | -72      |
# |    critic_loss     | 0.628    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 20703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.9     |
# |    ep_rew_mean     | 16.5     |
# |    success_rate    | 0.14     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 41       |
# |    time_elapsed    | 540      |
# |    total_timesteps | 22204    |
# | train/             |          |
# |    actor_loss      | -73.8    |
# |    critic_loss     | 32.1     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 21203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.5     |
# |    ep_rew_mean     | 16.2     |
# |    success_rate    | 0.12     |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 41       |
# |    time_elapsed    | 547      |
# |    total_timesteps | 22704    |
# | train/             |          |
# |    actor_loss      | -76.4    |
# |    critic_loss     | 0.735    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 21703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.9     |
# |    ep_rew_mean     | 15.4     |
# |    success_rate    | 0.11     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 41       |
# |    time_elapsed    | 556      |
# |    total_timesteps | 23204    |
# | train/             |          |
# |    actor_loss      | -76.5    |
# |    critic_loss     | 0.421    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 22203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | 14.1     |
# |    success_rate    | 0.09     |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 41       |
# |    time_elapsed    | 566      |
# |    total_timesteps | 23704    |
# | train/             |          |
# |    actor_loss      | -78.7    |
# |    critic_loss     | 0.386    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 22703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | 13.2     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 41       |
# |    time_elapsed    | 578      |
# |    total_timesteps | 24204    |
# | train/             |          |
# |    actor_loss      | -79.6    |
# |    critic_loss     | 19.3     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 23203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.8     |
# |    ep_rew_mean     | 12.1     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 41       |
# |    time_elapsed    | 602      |
# |    total_timesteps | 24704    |
# | train/             |          |
# |    actor_loss      | -80.2    |
# |    critic_loss     | 0.881    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 23703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | 11.8     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 41       |
# |    time_elapsed    | 610      |
# |    total_timesteps | 25204    |
# | train/             |          |
# |    actor_loss      | -82.2    |
# |    critic_loss     | 0.457    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 24203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | 10.4     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 41       |
# |    time_elapsed    | 620      |
# |    total_timesteps | 25704    |
# | train/             |          |
# |    actor_loss      | -84.3    |
# |    critic_loss     | 0.889    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 24703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 10.1     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 41       |
# |    time_elapsed    | 627      |
# |    total_timesteps | 26204    |
# | train/             |          |
# |    actor_loss      | -84.8    |
# |    critic_loss     | 0.461    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 25203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.76     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 41       |
# |    time_elapsed    | 637      |
# |    total_timesteps | 26704    |
# | train/             |          |
# |    actor_loss      | -85.9    |
# |    critic_loss     | 0.505    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 25703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.75     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 42       |
# |    time_elapsed    | 646      |
# |    total_timesteps | 27204    |
# | train/             |          |
# |    actor_loss      | -87.3    |
# |    critic_loss     | 0.44     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 26203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.69     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 42       |
# |    time_elapsed    | 658      |
# |    total_timesteps | 27704    |
# | train/             |          |
# |    actor_loss      | -86.6    |
# |    critic_loss     | 0.433    |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 26703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 10.4     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 42       |
# |    time_elapsed    | 666      |
# |    total_timesteps | 28204    |
# | train/             |          |
# |    actor_loss      | -89.3    |
# |    critic_loss     | 23.9     |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 27203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 10.7     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 42       |
# |    time_elapsed    | 673      |
# |    total_timesteps | 28704    |
# | train/             |          |
# |    actor_loss      | -89.3    |
# |    critic_loss     | 0.583    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 27703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 12       |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 42       |
# |    time_elapsed    | 680      |
# |    total_timesteps | 29204    |
# | train/             |          |
# |    actor_loss      | -92.2    |
# |    critic_loss     | 0.717    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 28203    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 12.8     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 42       |
# |    time_elapsed    | 704      |
# |    total_timesteps | 29704    |
# | train/             |          |
# |    actor_loss      | -92.5    |
# |    critic_loss     | 0.913    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 28703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 13.9     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 42       |
# |    time_elapsed    | 715      |
# |    total_timesteps | 30188    |
# | train/             |          |
# |    actor_loss      | -93      |
# |    critic_loss     | 0.581    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 29187    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 15.1     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 630      |
# |    fps             | 42       |
# |    time_elapsed    | 722      |
# |    total_timesteps | 30688    |
# | train/             |          |
# |    actor_loss      | -92.7    |
# |    critic_loss     | 28.3     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 29687    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 16.5     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 42       |
# |    time_elapsed    | 729      |
# |    total_timesteps | 31188    |
# | train/             |          |
# |    actor_loss      | -95.7    |
# |    critic_loss     | 0.327    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 30187    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.8     |
# |    ep_rew_mean     | 17.7     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 42       |
# |    time_elapsed    | 739      |
# |    total_timesteps | 31688    |
# | train/             |          |
# |    actor_loss      | -96.2    |
# |    critic_loss     | 0.55     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 30687    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | 18.8     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 42       |
# |    time_elapsed    | 748      |
# |    total_timesteps | 32165    |
# | train/             |          |
# |    actor_loss      | -96.7    |
# |    critic_loss     | 25.3     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 31164    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | 19.9     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 670      |
# |    fps             | 43       |
# |    time_elapsed    | 756      |
# |    total_timesteps | 32665    |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 0.605    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 31664    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | 20.5     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 43       |
# |    time_elapsed    | 767      |
# |    total_timesteps | 33165    |
# | train/             |          |
# |    actor_loss      | -98.2    |
# |    critic_loss     | 0.759    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 32164    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.6     |
# |    ep_rew_mean     | 20.9     |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 690      |
# |    fps             | 42       |
# |    time_elapsed    | 783      |
# |    total_timesteps | 33665    |
# | train/             |          |
# |    actor_loss      | -98.6    |
# |    critic_loss     | 0.528    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 32664    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.4     |
# |    ep_rew_mean     | 20.4     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 43       |
# |    time_elapsed    | 793      |
# |    total_timesteps | 34144    |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 1.47     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 33143    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.3     |
# |    ep_rew_mean     | 20.6     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 710      |
# |    fps             | 42       |
# |    time_elapsed    | 815      |
# |    total_timesteps | 34630    |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 26       |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 33629    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.2     |
# |    ep_rew_mean     | 20.4     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 42       |
# |    time_elapsed    | 825      |
# |    total_timesteps | 35113    |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 27.8     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 34112    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49       |
# |    ep_rew_mean     | 19.9     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 730      |
# |    fps             | 42       |
# |    time_elapsed    | 831      |
# |    total_timesteps | 35587    |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 1.5      |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 34586    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | 19.3     |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 42       |
# |    time_elapsed    | 841      |
# |    total_timesteps | 36082    |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 30.9     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 35081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | 18       |
# |    success_rate    | 0.07     |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 42       |
# |    time_elapsed    | 857      |
# |    total_timesteps | 36582    |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 1.18     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 35581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.2     |
# |    ep_rew_mean     | 17.1     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 42       |
# |    time_elapsed    | 863      |
# |    total_timesteps | 37082    |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 0.956    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 36081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.2     |
# |    ep_rew_mean     | 15.7     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 770      |
# |    fps             | 43       |
# |    time_elapsed    | 873      |
# |    total_timesteps | 37582    |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 62.5     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 36581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.2     |
# |    ep_rew_mean     | 14.4     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 43       |
# |    time_elapsed    | 881      |
# |    total_timesteps | 38082    |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 1.5      |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 37081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.2     |
# |    ep_rew_mean     | 13.2     |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 790      |
# |    fps             | 43       |
# |    time_elapsed    | 893      |
# |    total_timesteps | 38582    |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 0.567    |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 37581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.4     |
# |    ep_rew_mean     | 12.4     |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 43       |
# |    time_elapsed    | 903      |
# |    total_timesteps | 39082    |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 31.1     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 38081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.5     |
# |    ep_rew_mean     | 11.4     |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 810      |
# |    fps             | 42       |
# |    time_elapsed    | 930      |
# |    total_timesteps | 39582    |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 37.9     |
# |    learning_rate   | 4.97e-05 |
# |    n_updates       | 38581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.7     |
# |    ep_rew_mean     | 10.5     |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 42       |
# |    time_elapsed    | 939      |
# |    total_timesteps | 40082    |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 0.77     |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 39081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.81     |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 830      |
# |    fps             | 42       |
# |    time_elapsed    | 945      |
# |    total_timesteps | 40582    |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 43       |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 39581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.24     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 840      |
# |    fps             | 43       |
# |    time_elapsed    | 952      |
# |    total_timesteps | 41082    |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 0.511    |
# ...
# |    ep_rew_mean     | 10.2     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 970      |
# |    fps             | 43       |
# |    time_elapsed    | 1087     |
# |    total_timesteps | 47582    |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 0.71     |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 46581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.86     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 43       |
# |    time_elapsed    | 1094     |
# |    total_timesteps | 48082    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 1.86     |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 47081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.82     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 990      |
# |    fps             | 44       |
# |    time_elapsed    | 1103     |
# |    total_timesteps | 48582    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 0.642    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 47581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.45     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 44       |
# |    time_elapsed    | 1113     |
# |    total_timesteps | 49082    |
# | train/             |          |
# |    actor_loss      | -141     |
# |    critic_loss     | 1.52     |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 48081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.14     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1010     |
# |    fps             | 43       |
# |    time_elapsed    | 1134     |
# |    total_timesteps | 49582    |
# | train/             |          |
# |    actor_loss      | -139     |
# |    critic_loss     | 1.56     |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 48581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 9.21     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1020     |
# |    fps             | 43       |
# |    time_elapsed    | 1141     |
# |    total_timesteps | 50082    |
# | train/             |          |
# |    actor_loss      | -141     |
# |    critic_loss     | 1.31     |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 49081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.83     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1030     |
# |    fps             | 43       |
# |    time_elapsed    | 1156     |
# |    total_timesteps | 50582    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 0.653    |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 49581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.86     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1040     |
# |    fps             | 43       |
# |    time_elapsed    | 1163     |
# |    total_timesteps | 51082    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 0.81     |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 50081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.47     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1050     |
# |    fps             | 43       |
# |    time_elapsed    | 1172     |
# |    total_timesteps | 51582    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 0.64     |
# |    learning_rate   | 4.95e-05 |
# |    n_updates       | 50581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.2      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1060     |
# |    fps             | 44       |
# |    time_elapsed    | 1179     |
# |    total_timesteps | 52082    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 0.431    |
# |    learning_rate   | 4.95e-05 |
# |    n_updates       | 51081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.46     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1070     |
# |    fps             | 44       |
# |    time_elapsed    | 1185     |
# |    total_timesteps | 52582    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 0.61     |
# |    learning_rate   | 4.95e-05 |
# |    n_updates       | 51581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.67     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1080     |
# |    fps             | 44       |
# |    time_elapsed    | 1193     |
# |    total_timesteps | 53082    |
# | train/             |          |
# |    actor_loss      | -144     |
# |    critic_loss     | 0.693    |
# |    learning_rate   | 4.95e-05 |
# |    n_updates       | 52081    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 8.56     |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 1090     |
# |    fps             | 44       |
# |    time_elapsed    | 1202     |
# |    total_timesteps | 53582    |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 0.813    |
# |    learning_rate   | 4.95e-05 |
# |    n_updates       | 52581    |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 56
#      48     model.action_noise = (
#      49         action_noise
#      50     )
#      52 callback = SuccessThresholdCallback(
#      53     success_threshold=0.9, check_freq=1000, window_size=200, verbose=0
#      54 )
# ---> 56 model.learn(
#      57     total_timesteps=timesteps,
#      58     log_interval=10,
#      59     tb_log_name=run_id,
#      60     reset_num_timesteps=(i == 0),
#      61     callback=[callback, noise_cb],
#      62 )
#      63 model.save(model_path)
#      64 print(f"Saved model to: {model_path}\n")
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/ddpg/ddpg.py:123, in DDPG.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     114 def learn(
#     115     self: SelfDDPG,
#     116     total_timesteps: int,
#    (...)
#     121     progress_bar: bool = False,
#     122 ) -> SelfDDPG:
# --> 123     return super().learn(
#     124         total_timesteps=total_timesteps,
#     125         callback=callback,
#     126         log_interval=log_interval,
#     127         tb_log_name=tb_log_name,
#     128         reset_num_timesteps=reset_num_timesteps,
#     129         progress_bar=progress_bar,
#     130     )
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/td3/td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/rendering.py:350, in RecordVideo.step(self, action)
#     346 def step(
#     347     self, action: ActType
#     348 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     349     """Steps through the environment using action, recording observations if :attr:`self.recording`."""
# --> 350     obs, rew, terminated, truncated, info = self.env.step(action)
#     351     self.step_id += 1
#     353     if self.step_trigger and self.step_trigger(self.step_id):
#
# File ~/.local/lib/python3.8/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/.local/lib/python3.8/site-packages/panda_gym/envs/core.py:319, in RobotTaskEnv.step(self, action)
#     317 self.robot.set_action(action)
#     318 self.sim.step()
# --> 319 observation = self._get_obs()
#     320 # An episode is terminated iff the agent has reached the target
#     321 terminated = bool(self.task.is_success(observation["achieved_goal"], self.task.get_goal()))
#
# File ~/.local/lib/python3.8/site-packages/panda_gym/envs/core.py:266, in RobotTaskEnv._get_obs(self)
#     265 def _get_obs(self) -> Dict[str, np.ndarray]:
# --> 266     robot_obs = self.robot.get_obs().astype(np.float32)  # robot state
#     267     task_obs = self.task.get_obs().astype(np.float32)  # object position, velococity, etc...
#     268     observation = np.concatenate([robot_obs, task_obs])
#
# File ~/ros_ws/visioncraft/envs/locobot.py:213, in Locobot.get_obs(self)
#     207 """Get observation of robot state.
#     208
#     209 Returns:
#     210     np.ndarray: Observation array containing end-effector position, velocity and gripper width if not blocked
#     211 """
#     212 ee_position = self.get_ee_position()
# --> 213 ee_velocity = self.get_ee_velocity()
#     215 if not self.block_gripper:
#     216     fingers_width = self.get_fingers_width()
#
# File ~/ros_ws/visioncraft/envs/locobot.py:242, in Locobot.get_ee_velocity(self)
#     240 def get_ee_velocity(self) -> np.ndarray:
#     241     """Returns the velocity of the end-effector as (vx, vy, vz)"""
# --> 242     return self.get_link_velocity(self.ee_link)
#
# File ~/.local/lib/python3.8/site-packages/panda_gym/envs/core.py:99, in PyBulletRobot.get_link_velocity(self, link)
#      90 def get_link_velocity(self, link: int) -> np.ndarray:
#      91     """Returns the velocity of a link as (vx, vy, vz)
#      92
#      93     Args:
#    (...)
#      97         np.ndarray: Velocity as (vx, vy, vz)
#      98     """
# ---> 99     return self.sim.get_link_velocity(self.body_name, link)
#
# File ~/.local/lib/python3.8/site-packages/panda_gym/pybullet.py:258, in PyBullet.get_link_velocity(self, body, link)
#     248 def get_link_velocity(self, body: str, link: int) -> np.ndarray:
#     249     """Get the velocity of the link of the body.
#     250
#     251     Args:
#    (...)
#     256         np.ndarray: The velocity, as (vx, vy, vz).
#     257     """
# --> 258     velocity = self.physics_client.getLinkState(self._bodies_idx[body], link, computeLinkVelocity=True)[6]
#     259     return np.array(velocity)
#
# KeyboardInterrupt:
